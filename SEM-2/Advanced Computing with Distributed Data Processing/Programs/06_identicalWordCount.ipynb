# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepsphere-AI/BCA/blob/main/SEM-2/Advanced%20Computing%20with%20Distributed%20Data%20Processing/Programs/06_identicalWordCount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ***********************************************************************************************
  
  # File Name 	:   06_identicalWordCount.ipynb
  # Purpose 	  :   Create an application using Apache Spark for identical word count 
  # Author	    :   Deepsphere.ai
  # Reviewer 	  :   Jothi Periasamy
  # Date        :   08/02/2023 
  # Version	    :   1.0	
  
# ***********************************************************************************************

## Program Description : The objective of program is counting identical word in the given text file using pyspark.

## Python Development Environment & Runtime - Python, Anaconda

# ***********************************************************************************************

# installation for pyspark
# !pip install pyspark

from pyspark import SparkConf, SparkContext
import urllib.request

# Set up the Spark configuration 

conf = SparkConf().setAppName("IdenticalWordCount")
sc = SparkContext(conf=conf)

# Retrive file from path

path="https://raw.githubusercontent.com/Deepsphere-AI/BCA/main/SEM-2/Advanced%20Computing%20with%20Distributed%20Data%20Processing/Programs/content/demo.txt"

urllib.request.urlretrieve(path,"demo.txt")

# Replace punctuations

with open("/content/demo.txt","r") as fi:
  content=fi.read()
  punch=[".",","]
  for i in punch:
    for j in content:
      if i == j:
        content=content.replace(i,"")

with open("/content/input.txt","w") as input:
  input.write(content)

# Read in the documents as RDD ( Resilient Distributed Dataset )

doc1 = sc.textFile("/content/input.txt")

# Perform identical Word Count on the documents

vAR_wordCount1 = doc1.flatMap(lambda line: line.split(" ")) \
                .map(lambda word: (word, 1)) \
                .reduceByKey(lambda a, b: a + b)

# Print the result

vAR_a=vAR_wordCount1.collect()
vAR_unique_word_count=len(vAR_a)

print("\n******************************** OUTPUT ****************************************\n")

print("Unique word count : ",vAR_unique_word_count ,"\n\n")

print("Identical Word Count : \n")
for i in vAR_a:
  print(i[0]+" => ",i[1])

print("************************************************************************")
sc.stop()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.4/281.4 MB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 9.8 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845512 sha256=5ceba12c7df59a4bef858c052d2f2601deb7e0cc4bd569728120d9b0a1e5928b
#   Stored in directory: /root/.cache/pip/wheels/43/dc/11/ec201cd671da62fa9c5cc77078235e40722170ceba231d7598
# Successfully built pyspark
# ...
#
# ******************************** OUTPUT ****************************************
#
# Unique word count :  74
#
#
# Similarity Word Count :
#
# learning =>  4
# is =>  1
# of =>  2
# broader =>  1
# family =>  1
# machine =>  2
# based =>  1
# artificial =>  1
# neural =>  4
# networks =>  5
# representation =>  1
# supervised =>  1
# semi-supervised =>  1
# Deep-learning =>  1
# ...
